# %%
import pandas as pd
import pandas_gbq
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(
    '../../secret.json',
    scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

path = 'Copy of Hungerstation - Keeta Competitive Data Extract (01.11.2024) - Sheet4.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   Global Entity\       Logistics Area Source SF Status Raw  \
# 0          HS_SA            logistics  keeta      No Match
# 1          HS_SA  logistics_proximity  keeta      No Match
# 2          HS_SA  logistics_proximity  keeta      No Match
# 3          HS_SA            logistics  keeta      No Match
# 4          HS_SA                sales  keeta      No Match
#
#                     Vendor name  Vendor Grade    City  \
# 0   Akbar Al Bukhari Restaurant           NaN  Riyadh
# 1  Al Baraka Bukhari Restaurant           NaN  Riyadh
# 2           Al Zalal Restaurant           NaN  Riyadh
# 3   Alam Althura Markets Almajd           NaN  Riyadh
# 4                       Alstuor           NaN  Riyadh
#
#                                              Address  Latitude  Longitude  \
# 0               Badr, Al Imam Malik Rd, Riyadh 14724   24.5486    46.7070
# 1         Arafat Rd، 4451 7244 فتح مكة, Riyadh 14724   24.5402    46.7132
# 2  3751 7503 Prince Mamduh Bin Abdulaziz St, As S...   24.7101    46.6926
# 3  4210 Eastern Ring Branch Rd, Ar Rabwah, 6838, ...   24.6799    46.7761
# 4  JQ33+JG7, Al Mansourah, Riyadh 12694, Saudi Ar...   24.6041    46.7538
#
#           Phone                                       Main Cuisine  Lead ID  \
# 0           NaN                                      Arabic, Saudi   453255
# 1           NaN                       Arabic, Saudi, Meat, Bokhari   469890
# 2  9.661128e+11  Asian, Pakistani, Fine Dining, Meat, Local Fla...   489464
# 3           NaN                                    Dessert, Snacks   492730
# 4           NaN                          Fast Food, Shawarma, Meat   580340
#
#                     Accuracy        Status        Handler email    GRID
# 0  Invalid lead (Add reason)  Already exist    Bandar Alshathri  HA7S0F
# 1  Invalid lead (Add reason)  Already exist        Ahmed khalil  HRBMVS
# 2  Invalid lead (Add reason)      Duplicate  Mohammad Nasreddin     NaN
# 3  Invalid lead (Add reason)  Already exist  Mohammad Nasreddin  4CUZPO
# 4  Invalid lead (Add reason)  Already exist    Bandar Alshathri  4CJ71O

# %%
grids = df['GRID'].unique().tolist()

# %%
len(grids)
# Out:
# 52

# %%
grids
# Out:
# ['HA7S0F',
#  'HRBMVS',
#  nan,
#  '4CUZPO',
#  '4CJ71O',
#  'HZXYHI',
#  'HAGA7N',
#  'HR30VK',
#  'HA9BU6',
#  'HADJAO',
#  'HAWRTB',
#  '4FBZ8Y',
#  'HWEF7E',
#  '4CMYE7',
#  'HREL4Z',
#  'HWIUFY',
#  '4CCFDW',
#  'HA7C6L',
#  '4FBU6H',
#  'HAXGW9',
#  'HWSJHO',
#  'HR8AX1',
#  '4CX2A7',
#  'HWUF53',
#  'HWV6OH',
#  '4CJE79',
#  'HREK1A',
#  'HADY57',
#  '4FB7NC',
#  'HWX5AU',
#  'HRE5M1',
#  'HANHE1',
#  '4C0VH1',
#  '4FI7GQ',
#  '4FBKZC',
#  '4F668U',
#  'HAP8ZY',
#  'HAMMCB',
#  '4CJEEF',
#  'HR6N3L',
#  '4F6O1P',
#  '4FBM5R',
#  '4C48UL',
#  '4FB0YG',
#  'HA0YB4',
#  'HAW09D',
#  '4F2DKL',
#  'HRHDOQ',
#  '4COBEU',
#  'HRG69U',
#  '4C2QOH',
#  'HR9N3L']

# %%
# Remove nan
len([grid for grid in grids if isinstance(grid,str)])
# Out:
# 51

# %%
grid_list_query = "('" + "', '".join(str(grid) for grid in grids if isinstance(grid,str)) + "')"

# %%
grid_list_query
# Out:
# "('HA7S0F', 'HRBMVS', '4CUZPO', '4CJ71O', 'HZXYHI', 'HAGA7N', 'HR30VK', 'HA9BU6', 'HADJAO', 'HAWRTB', '4FBZ8Y', 'HWEF7E', '4CMYE7', 'HREL4Z', 'HWIUFY', '4CCFDW', 'HA7C6L', '4FBU6H', 'HAXGW9', 'HWSJHO', 'HR8AX1', '4CX2A7', 'HWUF53', 'HWV6OH', '4CJE79', 'HREK1A', 'HADY57', '4FB7NC', 'HWX5AU', 'HRE5M1', 'HANHE1', '4C0VH1', '4FI7GQ', '4FBKZC', '4F668U', 'HAP8ZY', 'HAMMCB', '4CJEEF', 'HR6N3L', '4F6O1P', '4FBM5R', '4C48UL', '4FB0YG', 'HA0YB4', 'HAW09D', '4F2DKL', 'HRHDOQ', '4COBEU', 'HRG69U', '4C2QOH', 'HR9N3L')"

# %%
# Run a query
query = f"""
select 
global_entity_id, 
lead_id,
lead_source,
restaurant_name,
restaurant_area,
restaurant_address,
restaurant_post_code,
restaurant_lat,
restaurant_long
from `dh-global-sales-data.leadgen_cl.vendor_complete`
where lead_id in {grid_list_query}
"""

df_sf_data = pandas_gbq.read_gbq(query, project_id=credentials.project_id, credentials=credentials)
# Out:
# /opt/homebrew/anaconda3/envs/vm_analysis/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2379: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(

# %%
df_merged = df.merge(df_sf_data, how='left', left_on='GRID', right_on='lead_id')

# %%
df_merged
# Out:
#    Global Entity\       Logistics Area Source SF Status Raw  \
# 0           HS_SA            logistics  keeta      No Match
# 1           HS_SA  logistics_proximity  keeta      No Match
# 2           HS_SA  logistics_proximity  keeta      No Match
# 3           HS_SA            logistics  keeta      No Match
# 4           HS_SA                sales  keeta      No Match
# ..            ...                  ...    ...           ...
# 62          HS_SA                sales  keeta      No Match
# 63          HS_SA                sales  keeta      No Match
# 64          HS_SA            logistics  keeta      No Match
# 65          HS_SA                sales  keeta      No Match
# 66          HS_SA                sales  keeta      No Match
#
#                      Vendor name  Vendor Grade      City  \
# 0    Akbar Al Bukhari Restaurant           NaN    Riyadh
# 1   Al Baraka Bukhari Restaurant           NaN    Riyadh
# 2            Al Zalal Restaurant           NaN    Riyadh
# 3    Alam Althura Markets Almajd           NaN    Riyadh
# 4                        Alstuor           NaN    Riyadh
# ..                           ...           ...       ...
# 62                  تراينقل سويت           NaN    Riyadh
# 63                       تكالافا           NaN  Al-Kharj
# 64               ذا رد باستا كَب           NaN    Riyadh
# 65               ذا رد باستا كَب           NaN    Riyadh
# 66            مقلوبة ® | Maqloba           NaN    Riyadh
#
#                                               Address  Latitude  Longitude  \
# 0                Badr, Al Imam Malik Rd, Riyadh 14724   24.5486    46.7070
# 1          Arafat Rd، 4451 7244 فتح مكة, Riyadh 14724   24.5402    46.7132
# 2   3751 7503 Prince Mamduh Bin Abdulaziz St, As S...   24.7101    46.6926
# 3   4210 Eastern Ring Branch Rd, Ar Rabwah, 6838, ...   24.6799    46.7761
# 4   JQ33+JG7, Al Mansourah, Riyadh 12694, Saudi Ar...   24.6041    46.7538
# ..                                                ...       ...        ...
# 62  3001 Al Souweidi Al Aam, As Suwaidi, Riyadh 12794   24.5870    46.6679
# 63          Mosque, An Nuzhah, Al-Kharj, Saudi Arabia   24.1608    47.3461
# 64  RBBA4438، 4438، 7062 Al Madina Al Munawwarah R...   24.5978    46.6388
# 65  QP68+C8R, Saad Ibn Ayyub, An Nuzhah, Riyadh 12...   24.7611    46.7158
# 66               King Abdullah Rd, St, Al-Kharj 16272   24.1307    47.2675
#
#     ...    GRID global_entity_id  lead_id lead_source  \
# 0   ...  HA7S0F            HS_SA   HA7S0F  salesforce
# 1   ...  HRBMVS            HS_SA   HRBMVS  salesforce
# 2   ...     NaN              NaN      NaN         NaN
# 3   ...  4CUZPO            HS_SA   4CUZPO  salesforce
# 4   ...  4CJ71O            HS_SA   4CJ71O  salesforce
# ..  ...     ...              ...      ...         ...
# 62  ...  4COBEU            HS_SA   4COBEU  salesforce
# 63  ...  HRG69U            HS_SA   HRG69U  salesforce
# 64  ...  4C2QOH            HS_SA   4C2QOH  salesforce
# 65  ...     NaN              NaN      NaN         NaN
# 66  ...  HR9N3L              NaN      NaN         NaN
#
#                                       restaurant_name     restaurant_area  \
# 0   Rukn Akbar Al Bukhari Restaurants: An Nasim Al...  An Nasim Al Gharbi
# 1                              Dhawq qand : Al Marwah           Al Marwah
# 2                                                 NaN                 NaN
# 3                                          Corn World           As Safraa
# 4                              Cleaver , Al Mansourah        Al Mansourah
# ..                                                ...                 ...
# 62                                     Triangle Sweet              Masiaf
# 63                              Tikkalava : An Nuzhah           An Nuzhah
# 64                      The Red Pasta Cup  : Al Manar            Al Manar
# 65                                                NaN                 NaN
# 66                                                NaN                 NaN
#
#                                    restaurant_address restaurant_post_code  \
# 0                                Omar Bin Abdullah ST                14234
# 1   6806 Al Khalil Ibn Ahmad, Al Marwah, 3790, Riy...                14721
# 2                                                 NaN                  NaN
# 3                26.36760976481661, 43.96233186537955                 None
# 4              24.604185707693016, 46.753782342328556                 None
# ..                                                ...                  ...
# 62                     24.763962629927736, 46.6805432                 None
# 63                              طريق عمر بن عبدالعزيز                11932
# 64             26.356453269947043, 43.934073821953476                 None
# 65                                                NaN                  NaN
# 66                                                NaN                  NaN
#
#    restaurant_lat restaurant_long
# 0       24.722327       46.835070
# 1       24.546749       46.688294
# 2             NaN             NaN
# 3       26.367427       43.962475
# 4       24.604063       46.753813
# ..            ...             ...
# 62      24.763909       46.680581
# 63      24.160817       47.346120
# 64      26.356409       43.934086
# 65            NaN             NaN
# 66            NaN             NaN
#
# [67 rows x 26 columns]

# %%
import math

def haversine(lat1, lon1, lat2, lon2) -> float:
    """
    Returns haversine distance in *km*
    """
    # Convert coordinates from degrees to radians
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (
        math.sin(dlat / 2) ** 2
        + math.cos(lat1) * math.cos(lat2) * math.sin(dlon / 2) ** 2
    )
    c = 2 * math.asin(math.sqrt(a))

    # Radius of earth in kilometers is 6371
    km = 6371 * c
    return km

# %%
df_merged["haversine_distance"]= df_merged.apply(lambda x: haversine(x.Latitude, x.Longitude, x.restaurant_lat, x.restaurant_long), axis=1)

# %%
df_merged[df_merged["haversine_distance"] > 1]
# Out:
#    Global Entity\       Logistics Area Source SF Status Raw  \
# 0           HS_SA            logistics  keeta      No Match
# 1           HS_SA  logistics_proximity  keeta      No Match
# 3           HS_SA            logistics  keeta      No Match
# 5           HS_SA  logistics_proximity  keeta      No Match
# 6           HS_SA            logistics  keeta      No Match
# 7           HS_SA                sales  keeta      No Match
# 8           HS_SA                sales  keeta      No Match
# 9           HS_SA  logistics_proximity  keeta      No Match
# 11          HS_SA            logistics  keeta      No Match
# 13          HS_SA            logistics  keeta      No Match
# 14          HS_SA                sales  keeta      No Match
# 15          HS_SA            logistics  keeta      No Match
# 17          HS_SA  logistics_proximity  keeta      No Match
# 18          HS_SA                sales  keeta      No Match
# 19          HS_SA            logistics  keeta      No Match
# 20          HS_SA  logistics_proximity  keeta      No Match
# 21          HS_SA            logistics  keeta      No Match
# 22          HS_SA  logistics_proximity  keeta      No Match
# 25          HS_SA                sales  keeta      No Match
# 27          HS_SA                sales  keeta      No Match
# 29          HS_SA            logistics  keeta      No Match
# 31          HS_SA                sales  keeta      No Match
# 32          HS_SA            logistics  keeta      No Match
# 33          HS_SA            logistics  keeta      No Match
# 34          HS_SA            logistics  keeta      No Match
# 35          HS_SA  logistics_proximity  keeta      No Match
# 36          HS_SA                sales  keeta      No Match
# 37          HS_SA                sales  keeta      No Match
# 38          HS_SA  logistics_proximity  keeta      No Match
# 39          HS_SA            logistics  keeta      No Match
# 41          HS_SA  logistics_proximity  keeta      No Match
# 43          HS_SA                sales  keeta      No Match
# 44          HS_SA  logistics_proximity  keeta      No Match
# 45          HS_SA                sales  keeta      No Match
# 46          HS_SA                sales  keeta      No Match
# 48          HS_SA  logistics_proximity  keeta      No Match
# 50          HS_SA                sales  keeta      No Match
# 52          HS_SA            logistics  keeta      No Match
# 53          HS_SA                sales  keeta      No Match
# 54          HS_SA                sales  keeta      No Match
# 55          HS_SA            logistics  keeta      No Match
# 56          HS_SA                sales  keeta      No Match
# 57          HS_SA                sales  keeta      No Match
# 58          HS_SA            logistics  keeta      No Match
# 59          HS_SA            logistics  keeta      No Match
# 60          HS_SA  logistics_proximity  keeta      No Match
# 61          HS_SA            logistics  keeta      No Match
# 62          HS_SA                sales  keeta      No Match
# 64          HS_SA            logistics  keeta      No Match
#
#                            Vendor name  Vendor Grade      City  \
# 0          Akbar Al Bukhari Restaurant           NaN    Riyadh
# 1         Al Baraka Bukhari Restaurant           NaN    Riyadh
# 3          Alam Althura Markets Almajd           NaN    Riyadh
# 5                    Amust Burger&More           NaN  Al-Kharj
# 6                    Anwaar Al Shawaya           NaN    Riyadh
# 7                         Anwaar Grill           NaN    Riyadh
# 8                 Anwar Dunia Broasted           NaN  Al-Kharj
# 9                Anwar Duniya Broasted           NaN  Al-Kharj
# 11                          Chai Walim           NaN    Riyadh
# 13                    Falafel Dar Arfa           NaN    Riyadh
# 14  fish auction center and restaurant           NaN    Riyadh
# 15                       Gloria Jean’s           NaN    Riyadh
# 17                           ili PIZZA           NaN    Riyadh
# 18                          Inah Grill           NaN    Riyadh
# 19                            Jabourih           NaN    Riyadh
# 20                     Kanz Alshawayah           NaN    Riyadh
# 21                     Kanz Alshawayah           NaN    Riyadh
# 22              Kareem meat restaurant           NaN  Al-Kharj
# 25     Mandi Riyof Al Kharj Restaurant           NaN  Al-Kharj
# 27                    Mirzas Fast Food           NaN    Riyadh
# 29                               Plant           NaN    Riyadh
# 31                         Sallah Shai           NaN    Riyadh
# 32                          Sea Shells           NaN    Riyadh
# 33                         Shaghaf Cup           NaN  Al-Kharj
# 34                      Shahi Fel Mokh           NaN    Riyadh
# 35                 Shalimar Restaurant           NaN    Riyadh
# 36                            Sharqeah           NaN    Riyadh
# 37                       Shawarma King           NaN  Al-Kharj
# 38                       Shawarma King           NaN  Al-Kharj
# 39                       Shawarma King           NaN  Al-Kharj
# 41                        Starbucks® -           NaN  Al-Kharj
# 43                              Teller           NaN    Riyadh
# 44                      The Pasta Guyz           NaN    Riyadh
# 45                        Tikka Corner           NaN    Riyadh
# 46         Top Tasting Pizza and Pasta           NaN    Riyadh
# 48                      Torta and More           NaN    Riyadh
# 50                        Wagyu Burger           NaN    Riyadh
# 52                    Wirsa Restaurant           NaN    Riyadh
# 53       Yemeni Traditional Restaurant           NaN    Riyadh
# 54                  Zad Al Aryaf Pizza           NaN  Al-Kharj
# 55                  Zad Al Aryaf Pizza           NaN  Al-Kharj
# 56                  Zad Al Aryaf Pizza           NaN  Al-Kharj
# 39                       5842+CH8، البرج، الخرج 16278   24.1563    47.3015
# 41                          King Abdulaziz RD Alkharj   24.1918    47.2771
# 43                         الستين, الشفا شارع, Riyadh   24.5509    46.6988
# 44  7527 Khafiya Valley, 2960, Badr, Riyadh 14718,...   24.5420    46.7256
# 45                   Jarir St, Al Malaz, Riyadh 12831   24.6712    46.7341
# 46  3989 Prince Mohammed Bin Saud Bin Faisal, Al K...   24.6289    46.7562
# 48                  Jarir, Riyadh 12833, Saudi Arabia   24.6862    46.7490
# 50  JP3J+WX5، المنصورة، الرياض 12684، المملكة العر...   24.6035    46.7344
# 52  Haroon Al Rashid Rd, As Sulay, Riyadh 14264, S...   24.6580    46.8122
# 53                          HQWF+H9F Al Aziziyah, 利雅得   24.5967    46.7734
# 54  59GC+QG7، الصفوة الثاني،, Secondal Safwa, Al-K...   24.1774    47.3713
# 55                  Al-Sahab District, Al-Kharj 16442   24.1456    47.3806
# 56  7016 Az Zubair Ibn Al Awwam, Al Faysaliyah, 34...   24.1600    47.3560
# 57                        568Q+MWQ, Al Hayathem 16256   24.1667    47.2399
# 58  9199 King Abdullah Road, Al Aliyah, OAJA 3697,...   24.1670    47.3528
# 59                            Mishrif, Al-Kharj 16432   24.1048    47.2936
# 60  3413 Abu Asim, 3413, Al Faysaliyah, Al-Kharj 1...   24.1608    47.3557
# 61                            JPQC+9X Thulaim, Riyadh   24.6384    46.7224
# 62  3001 Al Souweidi Al Aam, As Suwaidi, Riyadh 12794   24.5870    46.6679
# 64  RBBA4438، 4438، 7062 Al Madina Al Munawwarah R...   24.5978    46.6388
#
#     ...  global_entity_id lead_id  lead_source  \
# 0   ...             HS_SA  HA7S0F   salesforce
# 1   ...             HS_SA  HRBMVS   salesforce
# 3   ...             HS_SA  4CUZPO   salesforce
# 5   ...             HS_SA  HZXYHI   salesforce
# 6   ...             HS_SA  HAGA7N   salesforce
# 7   ...             HS_SA  HAGA7N   salesforce
# 8   ...             HS_SA  HR30VK   salesforce
# 9   ...             HS_SA  HR30VK   salesforce
# 11  ...             HS_SA  HADJAO   salesforce
# 13  ...             HS_SA  4FBZ8Y   salesforce
# 14  ...             HS_SA  HWEF7E   salesforce
# 15  ...             HS_SA  4CMYE7   salesforce
# 17  ...             HS_SA  HWIUFY   salesforce
# 18  ...             HS_SA  4CCFDW   salesforce
# 19  ...             HS_SA  HA7C6L   salesforce
# 20  ...             HS_SA  4FBU6H   salesforce
# 21  ...             HS_SA  4FBU6H   salesforce
# 22  ...             HS_SA  HAXGW9   salesforce
# 25  ...             HS_SA  4CX2A7   salesforce
# 27  ...             HS_SA  HWUF53   salesforce
# 29  ...             HS_SA  4CJE79   salesforce
# 31  ...             HS_SA  HADY57   salesforce
# 32  ...             HS_SA  4FB7NC   salesforce
# 33  ...             HS_SA  HWX5AU   salesforce
# 34  ...             HS_SA  HRE5M1   salesforce
# 35  ...             HS_SA  HANHE1   salesforce
# 36  ...             HS_SA  4C0VH1   salesforce
# 37  ...             HS_SA  4FI7GQ   salesforce
# 38  ...             HS_SA  4FI7GQ   salesforce
# 39  ...             HS_SA  4FI7GQ   salesforce
# 41  ...             HS_SA  4F668U   salesforce
# 43  ...             HS_SA  HAMMCB   salesforce
# 44  ...             HS_SA  4CJEEF   salesforce
# 45  ...             HS_SA  HR6N3L   salesforce
# 46  ...             HS_SA  4F6O1P   salesforce
# 48  ...             HS_SA  4FBM5R   salesforce
# 50  ...             HS_SA  4C48UL   salesforce
# 52  ...             HS_SA  HA0YB4   salesforce
# 53  ...             HS_SA  HAW09D   salesforce
# 54  ...             HS_SA  4F2DKL   salesforce
# 55  ...             HS_SA  4F2DKL   salesforce
# 56  ...             HS_SA  4F2DKL   salesforce
# 57  ...             HS_SA  4F2DKL   salesforce
# 58  ...             HS_SA  4F2DKL   salesforce
# 59  ...             HS_SA  4F2DKL   salesforce
# 60  ...             HS_SA  4F2DKL   salesforce
# 61  ...             HS_SA  HRHDOQ   salesforce
# 62  ...             HS_SA  4COBEU   salesforce
# 64  ...             HS_SA  4C2QOH   salesforce
#
#                                       restaurant_name  \
# 0   Rukn Akbar Al Bukhari Restaurants: An Nasim Al...
# 1                              Dhawq qand : Al Marwah
# 3                                          Corn World
# 5                                   AMUST BURGER&MORE
# 6                                   ANWAAR AL SHAWAYA
# 7                                   ANWAAR AL SHAWAYA
# 8                         Duniya broasted : An Nahdah
# 9                         Duniya broasted : An Nahdah
# 11                                         Chai Walim
# 13                                          Dar Arafa
# 14                            fish auction restaurant
# 15                             Gloria Jean's : Tuwaiq
# 17                                          ili PIZZA
# 18                          Inah Grill: East An Nasim
# 19                                           Jabourih
# 20                         Kanz Al Shawaya Restaurant
# 21                         Kanz Al Shawaya Restaurant
# 22                              Kareem Meat: Ad Dilam
# 25   Restaurants wamatabikh mandi alkharaj :  Mishrif
# 27                            ميرزا ​​للوجبات السريعة
# 29                                              Plant
# 31                                        Salleh Shai
# 32                                          Sea Shell
# 33                                        Shaghaf Cup
# 34                      Tea fi almukh : Dhahrat Laban
# 35                                SHALIMAR RESTAURANT
# 36                                           Sharqeah
# 37                                      Shawarma King
# 38                                      Shawarma King
# 39                                      Shawarma King
# 41                                         Starbucks®
# 43                                   Teller : Al Hazm
# 44                                     The Pasta Guyz
# 45                          Indian Corner:Al Humaylah
# 46                        Top Tasting Pizza and Pasta
# 48                                     Torta and More
# 50                                         Wagyu:Aqiq
# 52                                   Wirsa Restaurant
# 53                      Yemeni Traditional Restaurant
# 54                                 Zad Al Aryaf Pizza
# 55                                 Zad Al Aryaf Pizza
# 56                                 Zad Al Aryaf Pizza
# 57                                 Zad Al Aryaf Pizza
# 58                                 Zad Al Aryaf Pizza
# 59                                 Zad Al Aryaf Pizza
# 60                                 Zad Al Aryaf Pizza
# 61                           Zaiqa Restaurant:Thulaim
# 62                                     Triangle Sweet
# 64                      The Red Pasta Cup  : Al Manar
#
#                            restaurant_area  \
# 0                       An Nasim Al Gharbi
# 1                                Al Marwah
# 3                                As Safraa
# 5   Prince Sattam Bin Abdulaziz University
# 6                      Uraija Al Gharbiyah
# 7                      Uraija Al Gharbiyah
# 8                                An Nahdah
# 9                                An Nahdah
# 11                                 Al Waha
# 13                           Dhahrat Laban
# 14                                Al Muruj
# 15                                  Tuwaiq
# 17                                    Aqiq
# 18                           East An Nasim
# 19                                 Sahafah
# 20                              Al Khaleej
# 21                              Al Khaleej
# 22                                Ad Dilam
# 25                                 Mishrif
# 27                              Al Wizarat
# 29                              Al Azizyah
# 31                                Munsiyah
# 32                                    Aqiq
# 33  Prince Sattam Bin Abdulaziz University
# 34                           Dhahrat Laban
# 35    Al Khubar Al Janubiyah - Al Bayoniya
# 36                                  Narjis
# 37                           Dhahrat Laban
# 38                           Dhahrat Laban
# 39                           Dhahrat Laban
# 41                              Al Khuzama
# 43                                 Al Hazm
# 44                           Dhahrat Laban
# 45                             Al Humaylah
# 46                                 Alawali
# 48                              Al Isdihar
# 50                                    Aqiq
# 52                                 2صثثضصث
# 53                                    Badr
# 54                            Al Munyfiyah
# 55                            Al Munyfiyah
# 56                            Al Munyfiyah
# 57                            Al Munyfiyah
# 58                            Al Munyfiyah
# 59                            Al Munyfiyah
# 60                            Al Munyfiyah
# 61                                 Thulaim
# 62                                  Masiaf
# 64                                Al Manar
#
#                                    restaurant_address restaurant_post_code  \
# 0                                Omar Bin Abdullah ST                14234
# 1   6806 Al Khalil Ibn Ahmad, Al Marwah, 3790, Riy...                14721
# 3                26.36760976481661, 43.96233186537955                 None
# 5              King Abdullah Rd, الخزامى، الخرج 11942                 None
# 6                                                  11                 6907
# 7                                                  11                 6907
# 8      7878 طريق الملك فهد، النهضة، 2773، الخرج 16439                 2773
# 9      7878 طريق الملك فهد، النهضة، 2773، الخرج 16439                 2773
# 11                                                  1                 None
# 13                                       Taiba Street                13782
# 14                                                  4                 None
# 15              24.554660552879856, 46.53927753502466                 None
# 17                                                  0                 None
# 18                        النسيم الشرقي، الرياض 14242                14242
# 19  King Abdul Aziz Branch Rd, As Sahafah, Riyadh ...                13321
# 20                                                N/A                 None
# 21                                                N/A                 None
# 22  5590، الدلم 16323 7670, Ad Dilam 16323, Saudi ...                16323
# 25        2978، الخرج 16249، المملكة العربية السعودية                16249
# 27                                             123243                 None
# 29               24.59398880902422, 46.75716457230584                 None
# 31                                                  1                 None
# 32                                      Wadi As Sahil                13515
# 33              24.137525166394404, 47.27565922693096                 None
# 34                                            Taif St                12553
# 35                                         4th street                34611
# 36                               24.827751, 46.682321                 None
# 37                                  ظهرة لبن - الرياض                 None
# 38                                  ظهرة لبن - الرياض                 None
# 39                                  ظهرة لبن - الرياض                 None
# 41                                                  1                 None
